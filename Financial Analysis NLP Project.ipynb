# %%
import spacy
import pandas as pd

# %%
f=open ("stocks.tsv.txt", "r")
text_data= f.readlines()
print(text_data)
# Out:
# ['Symbol\tCompanyName\tIndustry\tMarketCap\n', 'A\tAgilent Technologies\tLife Sciences Tools & Services\t53.65B\n', 'AA\tAlcoa\tMetals & Mining\t9.25B\n', 'AAC\tAres Acquisition\tShell Companies\t1.22B\n', 'AACG\tATA Creativity Global\tDiversified Consumer Services\t90.35M\n', 'AADI\tAadi Bioscience\tPharmaceuticals\t104.85M\n', 'AAIC\tArlington Asset Investment\tMortgage Real Estate Investment Trus...\t120.92M\n', 'AAL\tAmerican Airlines\tAirlines\t12.27B\n', 'AAMC\tAltisource Asset Management\tReal Estate Management & Development\t57.74M\n', 'AAME\tAtlantic American\tInsurance\t80.01M\n', "AAN\tThe Aaron's Company\tSpecialty Retail\t857.00M\n", 'AAOI\tApplied Optoelectronics\tCommunications Equipment\t201.66M\n', 'AAON\tAAON, Inc.\tBuilding Products\t3.41B\n', 'AAP\tAdvance Auto Parts\tSpecialty Retail\t12.60B\n', 'AAPL\tApple\tTechnology Hardware, Storage & Periph...\t2,462.50B\n', 'AAQC\tAccelerate Acquisition\tShell Companies\t483.00M\n', 'AAT\tAmerican Assets Trust\tEquity Real Estate Investment Trusts...\t2.31B\n', 'AATC\tAutoscope Technologies\tScientific & Technical Instruments\t44.17M\n', 'AAU\tAlmaden Minerals\tMetals & Mining\t56.19M\n', 'AAWW\tAtlas Air Worldwide Holdings\tAir Freight & Logistics\t2.15B\n', 'AB\tAllianceBernstein\tCapital Markets\t5.17B\n', 'ABB\tABB Ltd.\tElectrical Equipment\t73.77B\n', 'ABBV\tAbbVie\tBiotechnology\t188.52B\n', 'ABC\tAmerisourceBergen\tHealth Care Providers & Services\t25.52B\n', 'ABCB\tAmeris Bancorp\tBanks\t3.25B\n', 'ABCL\tAbCellera Biologics\tBiotechnology\t5.29B\n', 'ABCM\tAbcam PLC\tBiotechnology\t4.76B\n', 'ABEO\tAbeona Therapeutics\tBiotechnology\t130.58M\n', 'ABEV\tAmbev\tBeverages\t48.73B\n', 'ABG\tAsbury Automotive Group\tSpecialty Retail\t3.31B\n', 'ABGI\tABG Acquisition I\tShell Companies\t187.42M\n', 'ABIO\tARCA biopharma\tBiotechnology\t43.95M\n', 'ABM\tABM Industries\tCommercial Services & Supplies\t3.11B\n', 'ABMD\tAbiomed\tHealth Care Equipment & Supplies\t16.39B\n', 'ABNB\tAirbnb\tHotels, Restaurants & Leisure\t103.85B\n', 'ABOS\tAcumen Pharmaceuticals\tBiotechnology\t657.08M\n', 'ABR\tArbor Realty Trust\tMortgage Real Estate Investment Trus...\t2.56B\n', 'ABSI\tAbsci\tBiotechnology\t1.27B\n', 'ABST\tAbsolute Software\tSoftware-Application\t584.39M\n', 'ABT\tAbbott Laboratories\tHealth Care Equipment & Supplies\t228.34B\n', 'ABTX\tAllegiance Bancshares\tBanks\t711.56M\n', 'ABUS\tArbutus Biopharma\tBiotechnology\t434.33M\n', 'ABVC\tABVC BioPharma\tBiotechnology\t85.65M\n', 'AC\tAssociated Capital Group\tCapital Markets\t814.56M\n', 'ACA\tArcosa\tConstruction & Engineering\t2.38B\n', 'ACAD\tACADIA Pharmaceuticals\tBiotechnology\t2.58B\n', 'ACAH\tAtlantic Coastal Acquisition\tShell Companies\t418.31M\n', 'ACB\tAurora Cannabis\tPharmaceuticals\t1.31B\n', 'ACBA\tAce Global Business Acquisition\tShell Companies\t52.80M\n', 'ACBI\tAtlantic Capital Bancshares\tBanks\t473.26M\n', 'ACC\tAmerican Campus Communities\tEquity Real Estate Investment Trusts...\t6.94B\n', 'ACCD\tAccolade\tHealth Care Technology\t3.12B\n', 'ACCO\tACCO Brands\tCommercial Services & Supplies\t857.47M\n', 'ACEL\tAccel Entertainment\tHotels, Restaurants & Leisure\t1.09B\n', 'ACER\tAcer Therapeutics\tPharmaceuticals\t38.35M\n', 'ACET\tAdicet Bio\tHealth Care Providers & Services\t242.32M\n', 'ACEV\tACE Convergence Acquisition\tShell Companies\t284.34M\n', 'ACGL\tArch Capital Group\tInsurance\t15.42B\n', 'ACH\tAluminum Corporation of China\tMetals & Mining\t22.20B\n', 'ACHC\tAcadia Healthcare Company\tHealth Care Providers & Services\t5.81B\n', 'ACHL\tAchilles Therapeutics\tBiotechnology\t250.12M\n', 'ACHV\tAchieve Life Sciences\tBiotechnology\t75.71M\n', 'ACI\tAlbertsons Companies\tGrocery Stores\t14.01B\n', 'ACIC\tAtlas Crest Investment\tShell Companies\t608.12M\n', 'ACII\tAtlas Crest Investment II\tShell Companies\t418.39M\n', 'ACIU\tAC Immune\tBiotechnology\t518.01M\n', 'ACIW\tACI Worldwide\tSoftware\t3.77B\n', 'ACKIT\tAckrell SPAC Partners I\tShell Companies\t143.53M\n', 'ACLS\tAxcelis Technolog ...

# %%
#text_data

# %%
df = pd.read_csv('stocks.tsv.txt', sep='\t')
print(df.head())
# Out:
#   Symbol            CompanyName                        Industry MarketCap
# 0      A   Agilent Technologies  Life Sciences Tools & Services    53.65B
# 1     AA                  Alcoa                 Metals & Mining     9.25B
# 2    AAC       Ares Acquisition                 Shell Companies     1.22B
# 3   AACG  ATA Creativity Global   Diversified Consumer Services    90.35M
# 4   AADI        Aadi Bioscience                 Pharmaceuticals   104.85M

# %%
symbols = df.Symbol.tolist()
companies = df.CompanyName.tolist()
print(symbols[:10])
#print(companies[:10])
# Out:
# ['A', 'AA', 'AAC', 'AACG', 'AADI', 'AAIC', 'AAL', 'AAMC', 'AAME', 'AAN']

# %% [markdown]
# ## Creating simply Entity Ruler.

# %%
nlp = spacy.blank("en")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6908/2595180598.py in <module>
# ----> 1 nlp = spacy.blank("en")
#
# ~\anaconda_installer\anaconda3\lib\site-packages\spacy\__init__.py in blank(name, vocab, config, meta)
#      72     # We should accept both dot notation and nested dict here for consistency
#      73     config = util.dot_to_dict(config)
# ---> 74     return LangClass.from_config(config, vocab=vocab, meta=meta)
#
# ~\anaconda_installer\anaconda3\lib\site-packages\spacy\language.py in from_config(cls, config, vocab, disable, exclude, meta, auto_fill, validate)
#    1750         # then we would load them twice at runtime: once when we make from config,
#    1751         # and then again when we load from disk.
# -> 1752         nlp = lang_cls(vocab=vocab, create_tokenizer=create_tokenizer, meta=meta)
#    1753         if after_creation is not None:
#    1754             nlp = after_creation(nlp)
#
# ~\anaconda_installer\anaconda3\lib\site-packages\spacy\language.py in __init__(self, vocab, max_length, meta, create_tokenizer, batch_size, **kwargs)
#     160         # points. The factory decorator applied to these functions takes care
#     161         # of the rest.
# --> 162         util.registry._entry_point_factories.get_all()
#     163
#     164         self._config = DEFAULT_CONFIG.merge(self.default_config)
#
# ~\anaconda_installer\anaconda3\lib\site-packages\catalogue\__init__.py in get_all(self)
#     107         result = {}
#     108         if self.entry_points:
# --> 109             result.update(self.get_entry_points())
#     110         for keys, value in REGISTRY.copy().items():
#     111             if len(self.namespace) == len(keys) - 1 and all(
#
# ~\anaconda_installer\anaconda3\lib\site-packages\catalogue\__init__.py in get_entry_points(self)
#     122         result = {}
#     123         for entry_point in AVAILABLE_ENTRY_POINTS.get(self.entry_point_namespace, []):
# --> 124             result[entry_point.name] = entry_point.load()
#     125         return result
#     126
#
# ~\anaconda_installer\anaconda3\lib\importlib\metadata.py in load(self)
#      75         """
#      76         match = self.pattern.match(self.value)
# ---> 77         module = import_module(match.group('module'))
#      78         attrs = filter(None, (match.group('attr') or '').split('.'))
#      79         return functools.reduce(getattr, attrs, module)
#
# ~\anaconda_installer\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda_installer\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda_installer\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda_installer\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda_installer\anaconda3\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~\anaconda_installer\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda_installer\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda_installer\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda_installer\anaconda3\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda_installer\anaconda3\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\anaconda_installer\anaconda3\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~\anaconda_installer\anaconda3\lib\site-packages\spacy_transformers\__init__.py in <module>
# ----> 1 from . import architectures
#       2 from . import annotation_setters
#       3 from . import span_getters
#       4 from .layers import TransformerModel
#       5 from .pipeline_component import Transformer, install_extensions
#
# ~\anaconda_installer\anaconda3\lib\site-packages\spacy_transformers\architectures.py in <module>
#       4 from spacy.tokens import Doc
#       5
# ----> 6 from .layers import TransformerModel, TransformerListener
#       7 from .layers import trfs2arrays, split_trf_batch
#       8 from .util import registry
#
# ~\anaconda_installer\anaconda3\lib\site-packages\spacy_transformers\layers\__init__.py in <module>
# ----> 1 from .listener import TransformerListener
#       2 from .transformer_model import TransformerModel
#       3 from .split_trf import split_trf_batch
#       4 from .trfs2arrays import trfs2arrays
#       5
#
# ~\anaconda_installer\anaconda3\lib\site-packages\spacy_transformers\layers\listener.py in <module>
#       2 from thinc.api import Model
#       3 from spacy.tokens import Doc
# ----> 4 from ..data_classes import TransformerData
#       5
#       6
#
# ~\anaconda_installer\anaconda3\lib\site-packages\spacy_transformers\data_classes.py in <module>
#       3 import torch
#       4 import numpy
# ----> 5 from transformers.tokenization_utils import BatchEncoding
#       6 from transformers.file_utils import ModelOutput
#       7 from thinc.types import Ragged, Floats2d, Floats3d, FloatsXd, Ints2d
#
# ImportError: cannot import name 'BatchEncoding' from 'transformers.tokenization_utils' (C:\Users\Dell\anaconda_installer\anaconda3\lib\site-packages\transformers\tokenization_utils.py)

# %%
#nlp.analyze_pipes()

# %%
ruler = nlp.add_pipe("entity_ruler")

# %%
#nlp.analyze_pipes()

# %%
#nlp = spacy.blank("en")
#ruler = nlp.add_pipe("entity_ruler")
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
patterns = []
for symbol in symbols:
    patterns.append({"label":"STOCK", "pattern": symbol})
    for l in letters:
        patterns.append({"label":"STOCK", "pattern": symbol+f".{l}"})
for company in companies:
    patterns.append({"label":"COMPANY", "pattern": company})
ruler.add_patterns(patterns)

# %%
#nlp.analyze_pipes()

# %%
## https://www.reuters.com/business/futures-rise-after-biden-xi-call-oil-bounce-2021-09-10/##

text = '''
Sept 10 (Reuters) - Wall Street's main indexes were subdued on Friday as signs of higher inflation and a drop in Apple shares following an unfavorable court ruling offset expectations of an easing in U.S.-China tensions.

Data earlier in the day showed U.S. producer prices rose solidly in August, leading to the biggest annual gain in nearly 11 years and indicating that high inflation was likely to persist as the pandemic pressures supply chains."

"Today's data on wholesale prices should be eye-opening for the Federal Reserve, as inflation pressures still don't appear to be easing and will likely continue to be felt by the consumer in the coming months," said Charlie Ripley, senior investment strategist for Allianz Investment Management.

Apple Inc (AAPL.O) fell 2.7% following a U.S. court ruling in "Fortnite" creator Epic Games' antitrust lawsuit that stroke down some of the iPhone maker's restrictions on how developers can collect payments in apps.

Sponsored by Advertising Partner
Sponsored Vedio
Watch to learn more
Report ad
Apple shares were set for their worst single-day fall since May this year, weighing on the Nasdaq (.IXIC) and the S&P 500 technology sub-index (.SPLRCT), which fell 0.1%.

Sentiment also took a hit from Cleveland Federal Reserve Bank President Loretta Mester's comments that she would still like the central bank to begin tapering asset purchases this year despite the weak August jobs report. 

Investors have paid keen attention to the labor market and data hinting towards higher inflation recently for hints on a timeline for the Federal Reserve to begin tapering its massive bond-buying program.

The S&P 500 has risen around 19% so far this year on support from dovish central bank policies and re-opening optimism, but concerns over rising coronavirus infections and accelerating inflation have lately stalled its advance.

The three main U.S. indexes got some support on Friday from news of a phone call between U.S. President Joe Biden and Chinese leader Xi Jinping that was taken as a positive sign which could bring a thaw in ties between the world's two most important trading partners.

At 1:01 p.m. ET, the Dow Jones Industrial Average (.DJI) was up 12.24 points, or 0.04%, at 34,891.62, the S&P 500 (.SPX) was up 2.83 points, or 0.06%, at 4,496.11, and the Nasdaq Composite (.IXIC) was up 12.85 points, or 0.08%, at 15,261.11.

Six of the eleven S&P 500 sub-indexes gained, with energy (.SPNY), materials (.SPLRCM) and consumer discretionary stocks (.SPLRCD) rising the most.

U.S.-listed Chinese e-commerce companies Alibaba and JD.com , music streaming company Tencent Music (TME.N) and electric car maker Nio Inc (NIO.N) all gained between 0.7% and 1.4%

Grocer Kroger Co (KR.N) dropped 7.1% after it said global supply chain disruptions, freight costs, discounts and wastage would hit its profit margins.

Advancing issues outnumbered decliners by a 1.12-to-1 ratio on the NYSE and by a 1.02-to-1 ratio on the Nasdaq.

The S&P index recorded 14 new 52-week highs and three new lows, while the Nasdaq recorded 49 new highs and 38 new lows.
'''

# %%
print(text)

# %%
doc = nlp(text)

# %%
print(len(text))
print(len(doc))

# %%
for ent in doc.ents:
    print(ent.text,ent.label_)

# %%
from spacy import displacy

# %%
displacy.render(doc, style="ent")

# %% [markdown]
# ## Making our model more accurate:-
#
# ## Capturing "two" as a COMPANY name

# %%
nlp = spacy.blank("en")
ruler = nlp.add_pipe("entity_ruler")
stops = ["two"]
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
patterns = []
for symbol in symbols:
    patterns.append({"label":"STOCK", "pattern": symbol})
    for l in letters:
        patterns.append({"label":"STOCK", "pattern": symbol+f".{l}"})
for company in companies:
    if company not in stops:
        patterns.append({"label":"COMPANY", "pattern": company})
ruler.add_patterns(patterns)

# %%
doc = nlp(text)

# %%
for ent in doc.ents:
    print(ent.text,ent.label_)

# %%
displacy.render(doc, style="ent")

# %% [markdown]
# ## Importing another dataset inorder to extract 'INDEX'  from Financial blob text data

# %%
df2 = pd.read_csv("indexes.tsv.txt",sep='\t')
df2.head()

# %%
index_Names = df2.IndexName.tolist()
index_symbols = df2.IndexSymbol.tolist()
print(index_Names)
print(index_symbols)

# %%
nlp = spacy.blank("en")
ruler = nlp.add_pipe("entity_ruler")
stops = ["two"]
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
patterns = []
for symbol in symbols:
    patterns.append({"label":"STOCK", "pattern": symbol})
    for l in letters:
        patterns.append({"label":"STOCK", "pattern": symbol+f".{l}"})
for company in companies:
    if company not in stops:
        patterns.append({"label":"COMPANY", "pattern": company})
for index in index_Names:
    patterns.append({"label":"INDEX", "pattern": index})
for index in index_symbols:
    patterns.append({"label":"INDEX", "pattern": index})
ruler.add_patterns(patterns)

# %%
doc = nlp(text)
for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# Apple COMPANY
# Apple COMPANY
# AAPL.O STOCK
# Apple COMPANY
# Nasdaq COMPANY
# ET STOCK
# Dow Jones Industrial Average INDEX
# Nasdaq COMPANY
# JD.com COMPANY
# TME.N STOCK
# NIO.N STOCK
# Kroger COMPANY
# KR.N STOCK
# Nasdaq COMPANY
# Nasdaq COMPANY

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br>Sept 10 (Reuters) - Wall Street's main indexes were subdued on Friday as signs of higher inflation and a drop in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  shares following an unfavorable court ruling offset expectations of an easing in U.S.-China tensions.</br></br>Data earlier in the day showed U.S. producer prices rose solidly in August, leading to the biggest annual gain in nearly 11 years and indicating that high inflation was likely to persist as the pandemic pressures supply chains.&quot;</br></br>&quot;Today's data on wholesale prices should be eye-opening for the Federal Reserve, as inflation pressures still don't appear to be easing and will likely continue to be felt by the consumer in the coming months,&quot; said Charlie Ripley, senior investment strategist for Allianz Investment Management.</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  Inc (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AAPL.O
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ) fell 2.7% following a U.S. court ruling in &quot;Fortnite&quot; creator Epic Games' antitrust lawsuit that stroke down some of the iPhone maker's restrictions on how developers can collect payments in apps.</br></br>Sponsored by Advertising Partner</br>Sponsored Vedio</br>Watch to learn more</br>Report ad</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  shares were set for their worst single-day fall since May this year, weighing on the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nasdaq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  (.IXIC) and the S&amp;P 500 technology sub-index (.SPLRCT), which fell 0.1%.</br></br>Sentiment also took a hit from Cleveland Federal Reserve Bank President Loretta Mester's comments that she would still like the central bank to begin tapering asset purchases this year despite the weak August jobs report. </br></br>Investors have paid keen attention to the labor market and data hinting towards higher inflation recently for hints on a timeline for the Federal Reserve to begin tapering its massive bond-buying program.</br></br>The S&amp;P 500 has risen around 19% so far this year on support from dovish central bank policies and re-opening optimism, but concerns over rising coronavirus infections and accelerating inflation have lately stalled its advance.</br></br>The three main U.S. indexes got some support on Friday from news of a phone call between U.S. President Joe Biden and Chinese leader Xi Jinping that was taken as a positive sign which could bring a thaw in ties between the world's two most important trading partners.</br></br>At 1:01 p.m.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ET
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# , the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dow Jones Industrial Average
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDEX</span>
# </mark>
#  (.DJI) was up 12.24 points, or 0.04%, at 34,891.62, the S&amp;P 500 (.SPX) was up 2.83 points, or 0.06%, at 4,496.11, and the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nasdaq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  Composite (.IXIC) was up 12.85 points, or 0.08%, at 15,261.11.</br></br>Six of the eleven S&amp;P 500 sub-indexes gained, with energy (.SPNY), materials (.SPLRCM) and consumer discretionary stocks (.SPLRCD) rising the most.</br></br>U.S.-listed Chinese e-commerce companies Alibaba and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JD.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  , music streaming company Tencent Music (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TME.N
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ) and electric car maker Nio Inc (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NIO.N
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ) all gained between 0.7% and 1.4%</br></br>Grocer
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kroger
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  Co (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     KR.N
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ) dropped 7.1% after it said global supply chain disruptions, freight costs, discounts and wastage would hit its profit margins.</br></br>Advancing issues outnumbered decliners by a 1.12-to-1 ratio on the NYSE and by a 1.02-to-1 ratio on the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nasdaq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
# .</br></br>The S&amp;P index recorded 14 new 52-week highs and three new lows, while the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nasdaq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  recorded 49 new highs and 38 new lows.</br></div></span>

# %% [markdown]
# ## Modifing Model inorder to extract "S&P 500"

# %%
nlp = spacy.blank("en")
ruler = nlp.add_pipe("entity_ruler")
stops = ["two"]
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
patterns = []
for symbol in symbols:
    patterns.append({"label":"STOCK", "pattern": symbol})
    for l in letters:
        patterns.append({"label":"STOCK", "pattern": symbol+f".{l}"})
for company in companies:
    if company not in stops:
        patterns.append({"label":"COMPANY", "pattern": company})
for index in index_Names:
    patterns.append({"label":"INDEX", "pattern": index})
    word = index.split()
    patterns.append({"label":"INDEX", "pattern": " ".join(word[:2])})
for index in index_symbols:
    patterns.append({"label":"INDEX", "pattern": index})
ruler.add_patterns(patterns)

# %%
doc = nlp(text)
for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# Apple COMPANY
# Apple COMPANY
# AAPL.O STOCK
# Apple COMPANY
# Nasdaq COMPANY
# S&P 500 INDEX
# S&P 500 INDEX
# ET STOCK
# Dow Jones Industrial Average INDEX
# S&P 500 INDEX
# Nasdaq COMPANY
# S&P 500 INDEX
# JD.com COMPANY
# TME.N STOCK
# NIO.N STOCK
# Kroger COMPANY
# KR.N STOCK
# Nasdaq COMPANY
# Nasdaq COMPANY

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br>Sept 10 (Reuters) - Wall Street's main indexes were subdued on Friday as signs of higher inflation and a drop in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  shares following an unfavorable court ruling offset expectations of an easing in U.S.-China tensions.</br></br>Data earlier in the day showed U.S. producer prices rose solidly in August, leading to the biggest annual gain in nearly 11 years and indicating that high inflation was likely to persist as the pandemic pressures supply chains.&quot;</br></br>&quot;Today's data on wholesale prices should be eye-opening for the Federal Reserve, as inflation pressures still don't appear to be easing and will likely continue to be felt by the consumer in the coming months,&quot; said Charlie Ripley, senior investment strategist for Allianz Investment Management.</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  Inc (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AAPL.O
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ) fell 2.7% following a U.S. court ruling in &quot;Fortnite&quot; creator Epic Games' antitrust lawsuit that stroke down some of the iPhone maker's restrictions on how developers can collect payments in apps.</br></br>Sponsored by Advertising Partner</br>Sponsored Vedio</br>Watch to learn more</br>Report ad</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  shares were set for their worst single-day fall since May this year, weighing on the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nasdaq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  (.IXIC) and the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S&amp;P 500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDEX</span>
# </mark>
#  technology sub-index (.SPLRCT), which fell 0.1%.</br></br>Sentiment also took a hit from Cleveland Federal Reserve Bank President Loretta Mester's comments that she would still like the central bank to begin tapering asset purchases this year despite the weak August jobs report. </br></br>Investors have paid keen attention to the labor market and data hinting towards higher inflation recently for hints on a timeline for the Federal Reserve to begin tapering its massive bond-buying program.</br></br>The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S&amp;P 500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDEX</span>
# </mark>
#  has risen around 19% so far this year on support from dovish central bank policies and re-opening optimism, but concerns over rising coronavirus infections and accelerating inflation have lately stalled its advance.</br></br>The three main U.S. indexes got some support on Friday from news of a phone call between U.S. President Joe Biden and Chinese leader Xi Jinping that was taken as a positive sign which could bring a thaw in ties between the world's two most important trading partners.</br></br>At 1:01 p.m.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ET
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# , the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dow Jones Industrial Average
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDEX</span>
# </mark>
#  (.DJI) was up 12.24 points, or 0.04%, at 34,891.62, the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S&amp;P 500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDEX</span>
# </mark>
#  (.SPX) was up 2.83 points, or 0.06%, at 4,496.11, and the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nasdaq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  Composite (.IXIC) was up 12.85 points, or 0.08%, at 15,261.11.</br></br>Six of the eleven
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S&amp;P 500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDEX</span>
# </mark>
#  sub-indexes gained, with energy (.SPNY), materials (.SPLRCM) and consumer discretionary stocks (.SPLRCD) rising the most.</br></br>U.S.-listed Chinese e-commerce companies Alibaba and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JD.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  , music streaming company Tencent Music (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TME.N
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ) and electric car maker Nio Inc (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NIO.N
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ) all gained between 0.7% and 1.4%</br></br>Grocer
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kroger
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  Co (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     KR.N
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ) dropped 7.1%

# %% [markdown]
# ## Importing another dataset inorder to extract more features likes "stock Exchange"

# %%
df3 = pd.read_csv("stock_exchanges.tsv.txt",sep='\t')
df3
# Out:
#     BloombergExchangeCode BloombergCompositeCode    Country  \
# 0                      AF                     AR  Argentina
# 1                      AO                     AU  Australia
# 2                      AT                     AU  Australia
# 3                      AV                    NaN    Austria
# 4                      BI                    NaN    Bahrain
# ..                    ...                    ...        ...
# 97                     UR                     US        USA
# 98                     UV                     US        USA
# 99                     UW                     US        USA
# 100                    VH                     VN    Vietnam
# 101                    VM                     VN    Vietnam
#
#                               Description ISOMIC Google Prefix EODcode  \
# 0       Bolsa de Comercio de Buenos Aires   XBUE           NaN      BA
# 1    National Stock Exchange of Australia   XNEC           NaN     NaN
# 2                       Asx - All Markets   XASX           ASX      AU
# 3                        Wiener Boerse Ag   XWBO           VIE      VI
# 4                          Bahrain Bourse   XBAH           NaN     NaN
# ..                                    ...    ...           ...     ...
# 97                  NASDAQ Capital Market   XNCM        NASDAQ      US
# 98                            OTC markets   OOTC       OTCMKTS      US
# 99                   NASDAQ Global Select   XNGS        NASDAQ      US
# 100                  Hanoi Stock Exchange   HSTC           NaN     NaN
# 101              Hochiminh Stock Exchange   XSTC           NaN      VN
#
#     NumStocks
# 0          12
# 1           1
# 2         875
# 3          38
# 4           4
# ..        ...
# 97      2,209
# 98      2,433
# 99      1,768
# 100         4
# 101        40
#
# [102 rows x 8 columns]

# %%
df3.columns
# Out:
# Index(['BloombergExchangeCode', 'BloombergCompositeCode', 'Country',
#        'Description', 'ISOMIC', 'Google Prefix', 'EODcode', 'NumStocks'],
#       dtype='object')

# %%
df3.rename(columns = {'Google Prefix':'Google_Prefix'}, inplace = True)
df3
# Out:
#     BloombergExchangeCode BloombergCompositeCode    Country  \
# 0                      AF                     AR  Argentina
# 1                      AO                     AU  Australia
# 2                      AT                     AU  Australia
# 3                      AV                    NaN    Austria
# 4                      BI                    NaN    Bahrain
# ..                    ...                    ...        ...
# 97                     UR                     US        USA
# 98                     UV                     US        USA
# 99                     UW                     US        USA
# 100                    VH                     VN    Vietnam
# 101                    VM                     VN    Vietnam
#
#                               Description ISOMIC Google_Prefix EODcode  \
# 0       Bolsa de Comercio de Buenos Aires   XBUE           NaN      BA
# 1    National Stock Exchange of Australia   XNEC           NaN     NaN
# 2                       Asx - All Markets   XASX           ASX      AU
# 3                        Wiener Boerse Ag   XWBO           VIE      VI
# 4                          Bahrain Bourse   XBAH           NaN     NaN
# ..                                    ...    ...           ...     ...
# 97                  NASDAQ Capital Market   XNCM        NASDAQ      US
# 98                            OTC markets   OOTC       OTCMKTS      US
# 99                   NASDAQ Global Select   XNGS        NASDAQ      US
# 100                  Hanoi Stock Exchange   HSTC           NaN     NaN
# 101              Hochiminh Stock Exchange   XSTC           NaN      VN
#
#     NumStocks
# 0          12
# 1           1
# 2         875
# 3          38
# 4           4
# ..        ...
# 97      2,209
# 98      2,433
# 99      1,768
# 100         4
# 101        40
#
# [102 rows x 8 columns]

# %%
exchanges = df3.ISOMIC.tolist() + df3.Google_Prefix.tolist() + df3.Description.tolist()

# %%
print(exchanges[:10])
# Out:
# ['XBUE', 'XNEC', 'XASX', 'XWBO', 'XBAH', 'XDHA', 'XBRU', 'BVMF', 'XCNQ', 'XTSE']

# %%
nlp = spacy.blank("en")
ruler = nlp.add_pipe("entity_ruler")
stops = ["two"]
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
patterns = []
for symbol in symbols:
    patterns.append({"label":"STOCK", "pattern": symbol})
    for l in letters:
        patterns.append({"label":"STOCK", "pattern": symbol+f".{l}"})
for company in companies:
    if company not in stops:
        patterns.append({"label":"COMPANY", "pattern": company})
for index in index_Names:
    patterns.append({"label":"INDEX", "pattern": index})
    word = index.split()
    patterns.append({"label":"INDEX", "pattern": " ".join(word[:2])})
for index in index_symbols:
    patterns.append({"label":"INDEX", "pattern": index})

for exg in exchanges:
    patterns.append({"label":"STOCK_EXCHANGE", "pattern": exg})
    
ruler.add_patterns(patterns)

# %% [markdown]
# ## Final report

# %%
doc = nlp(text)
for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# Apple COMPANY
# Apple COMPANY
# AAPL.O STOCK
# Apple COMPANY
# Nasdaq COMPANY
# S&P 500 INDEX
# S&P 500 INDEX
# ET STOCK
# Dow Jones Industrial Average INDEX
# S&P 500 INDEX
# Nasdaq COMPANY
# S&P 500 INDEX
# JD.com COMPANY
# TME.N STOCK
# NIO.N STOCK
# Kroger COMPANY
# KR.N STOCK
# NYSE STOCK_EXCHANGE
# Nasdaq COMPANY
# Nasdaq COMPANY

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br>Sept 10 (Reuters) - Wall Street's main indexes were subdued on Friday as signs of higher inflation and a drop in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  shares following an unfavorable court ruling offset expectations of an easing in U.S.-China tensions.</br></br>Data earlier in the day showed U.S. producer prices rose solidly in August, leading to the biggest annual gain in nearly 11 years and indicating that high inflation was likely to persist as the pandemic pressures supply chains.&quot;</br></br>&quot;Today's data on wholesale prices should be eye-opening for the Federal Reserve, as inflation pressures still don't appear to be easing and will likely continue to be felt by the consumer in the coming months,&quot; said Charlie Ripley, senior investment strategist for Allianz Investment Management.</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  Inc (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AAPL.O
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ) fell 2.7% following a U.S. court ruling in &quot;Fortnite&quot; creator Epic Games' antitrust lawsuit that stroke down some of the iPhone maker's restrictions on how developers can collect payments in apps.</br></br>Sponsored by Advertising Partner</br>Sponsored Vedio</br>Watch to learn more</br>Report ad</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  shares were set for their worst single-day fall since May this year, weighing on the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nasdaq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  (.IXIC) and the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S&amp;P 500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDEX</span>
# </mark>
#  technology sub-index (.SPLRCT), which fell 0.1%.</br></br>Sentiment also took a hit from Cleveland Federal Reserve Bank President Loretta Mester's comments that she would still like the central bank to begin tapering asset purchases this year despite the weak August jobs report. </br></br>Investors have paid keen attention to the labor market and data hinting towards higher inflation recently for hints on a timeline for the Federal Reserve to begin tapering its massive bond-buying program.</br></br>The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S&amp;P 500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDEX</span>
# </mark>
#  has risen around 19% so far this year on support from dovish central bank policies and re-opening optimism, but concerns over rising coronavirus infections and accelerating inflation have lately stalled its advance.</br></br>The three main U.S. indexes got some support on Friday from news of a phone call between U.S. President Joe Biden and Chinese leader Xi Jinping that was taken as a positive sign which could bring a thaw in ties between the world's two most important trading partners.</br></br>At 1:01 p.m.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ET
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# , the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dow Jones Industrial Average
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDEX</span>
# </mark>
#  (.DJI) was up 12.24 points, or 0.04%, at 34,891.62, the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S&amp;P 500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDEX</span>
# </mark>
#  (.SPX) was up 2.83 points, or 0.06%, at 4,496.11, and the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nasdaq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  Composite (.IXIC) was up 12.85 points, or 0.08%, at 15,261.11.</br></br>Six of the eleven
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S&amp;P 500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDEX</span>
# </mark>
#  sub-indexes gained, with energy (.SPNY), materials (.SPLRCM) and consumer discretionary stocks (.SPLRCD) rising the most.</br></br>U.S.-listed Chinese e-commerce companies Alibaba and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JD.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  , music streaming company Tencent Music (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TME.N
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ) and electric car maker Nio Inc (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NIO.N
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ) all gained between 0.7% and 1.4%</br></br>Grocer
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kroger
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  Co (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     KR.N
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ) dropped 7.1%
